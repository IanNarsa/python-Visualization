# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt

import seaborn as sns

# %%
data = pd.read_csv('data/museum_visitors.csv')

# %%
data.head()
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0  2014-01-01        24778              4486                     1581
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# 3                                  2824
# 4                                 10694

# %%
data['Avila Adobe'][0:6]
# Out:
# 0    24778
# 1    18976
# 2    25231
# 3    26989
# 4    36883
# 5    29487
# Name: Avila Adobe, dtype: int64

# %%
data[['Avila Adobe']][0:6]
# Out:
#    Avila Adobe
# 0        24778
# 1        18976
# 2        25231
# 3        26989
# 4        36883
# 5        29487

# %%
data.loc[:5,['Avila Adobe', 'Firehouse Museum']]
# Out:
#    Avila Adobe  Firehouse Museum
# 0        24778              4486
# 1        18976              4172
# 2        25231              7082
# 3        26989              6756
# 4        36883             10858
# 5        29487              5751

# %%
data.loc[data['Avila Adobe']==17163]
# Out:
#           Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 58  2018-11-01        17163              4082                     2385
#
#     America Tropical Interpretive Center
# 58                                  4562

# %%
data[data['Avila Adobe']>30000]
# Out:
#           Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 4   2014-05-01        36883             10858                     3676
# 6   2014-07-01        32378              5406                     2239
# 7   2014-08-01        37680              8619                     1769
# 16  2015-05-01        34383             12528                     4009
# 17  2015-06-01        30569              5377                     2544
# 18  2015-07-01        41242              6111                     3057
# 19  2015-08-01        30700              5383                     2415
# 28  2016-05-01        31728              9315                     4565
# 30  2016-07-01        31689              5602                     2776
# 40  2017-05-01        30029              8733                     5585
# 42  2017-07-01        30831              5242                     2939
#
#     America Tropical Interpretive Center
# 4                                  10694
# ...

# %%
data.iloc[:5]
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0  2014-01-01        24778              4486                     1581
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# 3                                  2824
# 4                                 10694

# %%
df5 = data.loc[5:5]

# %%
df5
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 5  2014-06-01        29487              5751                     2121
#
#    America Tropical Interpretive Center
# 5                                 11036

# %% [markdown]
# ### Another data set

# %%
df = pd.read_csv('data/pangan_19_20.csv', parse_dates = True)
df = df.drop(index = 85)


df.head()
# Out:
#          Date  Beras Beras Kualitas Bawah I (kg) Beras Kualitas Bawah II (kg)  \
# 0  02/09/2019  11700                       10650                        10250
# 1  03/09/2019  11700                       10650                        10250
# 2  04/09/2019  11700                       10650                        10250
# 3  05/09/2019  11700                       10650                        10250
# 4  06/09/2019  11700                       10650                        10250
#
#   Beras Kualitas Medium I (kg) Beras Kualitas Medium II (kg)  \
# 0                        11800                         11550
# 1                        11800                         11550
# 2                        11800                         11600
# 3                        11800                         11550
# 4                        11800                         11550
#
#   Beras Kualitas Super I (kg) Beras Kualitas Super II (kg) Daging Ayam  \
# ...

# %%
df['Daging Ayam']=df['Daging Ayam'].astype(int)
x = df['Date']
y = df['Daging Ayam']

plt.figure(figsize = (45, 15))
plt.xlabel("X label")
plt.ylabel("Y label")

plt.plot(x,y)
plt.xticks(rotation=90)
plt.show()

# %%
#df = df.astype(Date)
df.dtypes
# Out:
# Date                                    datetime64[ns]
# Beras                                           object
# Beras Kualitas Bawah I (kg)                     object
# Beras Kualitas Bawah II (kg)                    object
# Beras Kualitas Medium I (kg)                    object
# Beras Kualitas Medium II (kg)                   object
# Beras Kualitas Super I (kg)                     object
# Beras Kualitas Super II (kg)                    object
# Daging Ayam                                     object
# Daging Ayam Ras Segar (kg)                      object
# Daging Sapi                                     object
# Daging Sapi Kualitas 1 (kg)                     object
# Daging Sapi Kualitas 2 (kg)                     object
# Telur Ayam                                      object
# Telur Ayam Ras Segar (kg)                       object
# Bawang Merah                                    object
# Bawang Merah Ukuran Sedang (kg)                 object
# ...
