# %%
import pandas as pd

# %%
presensi = pd.read_csv('data/presensi.csv')
presensi
# Out:
#    no     kode                              matkul  jumlah kuliah  hadir  \
# 0   1  TI1668K           PRAKTIK KEAMANAN JARINGAN             14     13
# 1   2  TI1668T                   KEAMANAN JARINGAN             14     12
# 2   3  TI1670P    PRAKTIKUM PEMROGRAMAN WEB LANJUT             14     12
# 3   4  TI1671K  PRAKTIK SISTEM INFORMASI GEOGRAFIS             13     11
# 4   5  TI1671T          SISTEM INFORMASI GEOGRAFIS             14     13
# 5   6  TI1673K        PRAKTIK TEKNOLOGI BASIS DATA             12     12
# 6   7  TI1670T              PEMROGRAMAN WEB LANJUT             14     13
# 7   8  TI1675K                             SKRIPSI              0      0
#
#    alpha  persentase
# 0      1       92.86
# 1      2       85.71
# 2      2       85.71
# 3      2       84.62
# 4      1       92.86
# 5      0      100.00
# 6      1       92.86
# 7      0        0.00

# %%
presensi.head()
# Out:
#    no     kode                              matkul  jumlah kuliah  hadir  \
# 0   1  TI1668K           PRAKTIK KEAMANAN JARINGAN             14     13
# 1   2  TI1668T                   KEAMANAN JARINGAN             14     12
# 2   3  TI1670P    PRAKTIKUM PEMROGRAMAN WEB LANJUT             14     12
# 3   4  TI1671K  PRAKTIK SISTEM INFORMASI GEOGRAFIS             13     11
# 4   5  TI1671T          SISTEM INFORMASI GEOGRAFIS             14     13
#
#    alpha  persentase
# 0      1       92.86
# 1      2       85.71
# 2      2       85.71
# 3      2       84.62
# 4      1       92.86

# %%
presensi['alpha'].head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: alpha, dtype: int64

# %%
presensi[presensi['alpha']==1]
# Out:
#    no     kode                      matkul  jumlah kuliah  hadir  alpha  \
# 0   1  TI1668K   PRAKTIK KEAMANAN JARINGAN             14     13      1
# 4   5  TI1671T  SISTEM INFORMASI GEOGRAFIS             14     13      1
# 6   7  TI1670T      PEMROGRAMAN WEB LANJUT             14     13      1
#
#    persentase
# 0       92.86
# 4       92.86
# 6       92.86

# %%
presensi['alpha'][0]
# Out:
# 1

# %%
presensi.iloc[0]
# Out:
# no                                       1
# kode                               TI1668K
# matkul           PRAKTIK KEAMANAN JARINGAN
# jumlah kuliah                           14
# hadir                                   13
# alpha                                    1
# persentase                           92.86
# Name: 0, dtype: object

# %%
presensi.iloc[:,1]
# Out:
# 0    TI1668K
# 1    TI1668T
# 2    TI1670P
# 3    TI1671K
# 4    TI1671T
# 5    TI1673K
# 6    TI1670T
# 7    TI1675K
# Name: kode, dtype: object

# %%
presensi.iloc[0:3,1]
# Out:
# 0    TI1668K
# 1    TI1668T
# 2    TI1670P
# Name: kode, dtype: object

# %%
presensi.iloc[-5]
# Out:
# no                                                4
# kode                                        TI1671K
# matkul           PRAKTIK SISTEM INFORMASI GEOGRAFIS
# jumlah kuliah                                    13
# hadir                                            11
# alpha                                             2
# persentase                                    84.62
# Name: 3, dtype: object

# %%
presensi.iloc[-5:]
# Out:
#    no     kode                              matkul  jumlah kuliah  hadir  \
# 3   4  TI1671K  PRAKTIK SISTEM INFORMASI GEOGRAFIS             13     11
# 4   5  TI1671T          SISTEM INFORMASI GEOGRAFIS             14     13
# 5   6  TI1673K        PRAKTIK TEKNOLOGI BASIS DATA             12     12
# 6   7  TI1670T              PEMROGRAMAN WEB LANJUT             14     13
# 7   8  TI1675K                             SKRIPSI              0      0
#
#    alpha  persentase
# 3      2       84.62
# 4      1       92.86
# 5      0      100.00
# 6      1       92.86
# 7      0        0.00

# %%
presensi.loc[0, 'kode']
# Out:
# 'TI1668K'

# %%
presensi.loc[:,['kode', 'matkul', 'jumlah kuliah']]
# Out:
#       kode                              matkul  jumlah kuliah
# 0  TI1668K           PRAKTIK KEAMANAN JARINGAN             14
# 1  TI1668T                   KEAMANAN JARINGAN             14
# 2  TI1670P    PRAKTIKUM PEMROGRAMAN WEB LANJUT             14
# 3  TI1671K  PRAKTIK SISTEM INFORMASI GEOGRAFIS             13
# 4  TI1671T          SISTEM INFORMASI GEOGRAFIS             14
# 5  TI1673K        PRAKTIK TEKNOLOGI BASIS DATA             12
# 6  TI1670T              PEMROGRAMAN WEB LANJUT             14
# 7  TI1675K                             SKRIPSI              0

# %%
presensi.loc[:3,['kode', 'matkul', 'jumlah kuliah']]
# Out:
#       kode                              matkul  jumlah kuliah
# 0  TI1668K           PRAKTIK KEAMANAN JARINGAN             14
# 1  TI1668T                   KEAMANAN JARINGAN             14
# 2  TI1670P    PRAKTIKUM PEMROGRAMAN WEB LANJUT             14
# 3  TI1671K  PRAKTIK SISTEM INFORMASI GEOGRAFIS             13

# %%
presensi[['kode', 'matkul', 'jumlah kuliah']]
# Out:
#       kode                              matkul  jumlah kuliah
# 0  TI1668K           PRAKTIK KEAMANAN JARINGAN             14
# 1  TI1668T                   KEAMANAN JARINGAN             14
# 2  TI1670P    PRAKTIKUM PEMROGRAMAN WEB LANJUT             14
# 3  TI1671K  PRAKTIK SISTEM INFORMASI GEOGRAFIS             13
# 4  TI1671T          SISTEM INFORMASI GEOGRAFIS             14
# 5  TI1673K        PRAKTIK TEKNOLOGI BASIS DATA             12
# 6  TI1670T              PEMROGRAMAN WEB LANJUT             14
# 7  TI1675K                             SKRIPSI              0

# %%
presensi.set_index("no")
# Out:
#        kode                              matkul  jumlah kuliah  hadir  alpha  \
# no
# 1   TI1668K           PRAKTIK KEAMANAN JARINGAN             14     13      1
# 2   TI1668T                   KEAMANAN JARINGAN             14     12      2
# 3   TI1670P    PRAKTIKUM PEMROGRAMAN WEB LANJUT             14     12      2
# 4   TI1671K  PRAKTIK SISTEM INFORMASI GEOGRAFIS             13     11      2
# 5   TI1671T          SISTEM INFORMASI GEOGRAFIS             14     13      1
# 6   TI1673K        PRAKTIK TEKNOLOGI BASIS DATA             12     12      0
# 7   TI1670T              PEMROGRAMAN WEB LANJUT             14     13      1
# 8   TI1675K                             SKRIPSI              0      0      0
#
#     persentase
# no
# 1        92.86
# 2        85.71
# 3        85.71
# 4        84.62
# 5        92.86
# 6       100.00
# 7        92.86
# 8         0.00

# %%
presensi.kode == 'TI1668K'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: kode, dtype: bool

# %%
presensi.loc[presensi['jumlah kuliah'] == 14]
# Out:
#    no     kode                            matkul  jumlah kuliah  hadir  alpha  \
# 0   1  TI1668K         PRAKTIK KEAMANAN JARINGAN             14     13      1
# 1   2  TI1668T                 KEAMANAN JARINGAN             14     12      2
# 2   3  TI1670P  PRAKTIKUM PEMROGRAMAN WEB LANJUT             14     12      2
# 4   5  TI1671T        SISTEM INFORMASI GEOGRAFIS             14     13      1
# 6   7  TI1670T            PEMROGRAMAN WEB LANJUT             14     13      1
#
#    persentase
# 0       92.86
# 1       85.71
# 2       85.71
# 4       92.86
# 6       92.86
